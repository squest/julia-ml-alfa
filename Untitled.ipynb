# %%
plot(x=1:10, y=2.^rand(10),
     Scale.y_sqrt, Geom.point, Geom.smooth,
     Guide.xlabel("Stimulus"), Guide.ylabel("Response"), Guide.title("Dog Training"))
# Out:
# Plot(...)

# %%
Pkg.build("Winston")
# Out:
# INFO: Building Homebrew
# From https://github.com/Homebrew/homebrew
#    d9326f4..8770b7f  master     -> origin/master
# HEAD is now at 8770b7f glib-networking: update 2.44.0 bottle.
# From https://github.com/staticfloat/homebrew-juliadeps
#    6d4cd94..432b6ff  master     -> origin/master
# HEAD is now at 432b6ff Merge pull request #59 from staticfloat/staging
#    9694b03..48650d2  staging    -> origin/staging
# Uninstalling gnutls... (1020 files, 8.9M)
# ==> Downloading https://homebrew.bintray.com/bottles/gnutls-3.3.17.1.yosemite.bottle.tar.gz
# Already downloaded: /Users/questmac/Library/Caches/Homebrew.jl/gnutls-3.3.17.1.yosemite.bottle.tar.gz
# ==> Pouring gnutls-3.3.17.1.yosemite.bottle.tar.gz
# 🍺  /Users/questmac/.julia/v0.3/Homebrew/deps/usr/Cellar/gnutls/3.3.17.1: 1020 files, 8.8M
# To relink: brew unlink gnutls && brew link gnutls
# INFO: Building Cairo
# INFO: Building Tk
